# %%
# import necessary laibares
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px                              #Plotly is an open-source Python graphing library(great for building beautiful and interactive visualizations)
import plotly.graph_objs as go

# %%
df=pd.read_csv("/content/archive (72).zip")
df
# Out:
#          make model  priceUSD  year     condition  mileage(kilometers)  \
# 0       mazda     2      5500  2008  with mileage             162000.0
# 1       mazda     2      5350  2009  with mileage             120000.0
# 2       mazda     2      7000  2009  with mileage              61000.0
# 3       mazda     2      3300  2003  with mileage             265000.0
# 4       mazda     2      5200  2008  with mileage              97183.0
# ...       ...   ...       ...   ...           ...                  ...
# 56239  lancia  zeta      3650  2000  with mileage             290000.0
# 56240  lancia  zeta      4100  1999  with mileage             340000.0
# 56241  lancia  zeta      3600  1997  with mileage             354000.0
# 56242  lancia  zeta      3000  1997  with mileage             350000.0
# 56243  lancia  zeta      2950  1996  with mileage                  3.0
#
#       fuel_type  volume(cm3)     color transmission         drive_unit segment
# ...

# %%
df.head()
# Out:
#     make model  priceUSD  year     condition  mileage(kilometers) fuel_type  \
# 0  mazda     2      5500  2008  with mileage             162000.0    petrol
# 1  mazda     2      5350  2009  with mileage             120000.0    petrol
# 2  mazda     2      7000  2009  with mileage              61000.0    petrol
# 3  mazda     2      3300  2003  with mileage             265000.0    diesel
# 4  mazda     2      5200  2008  with mileage              97183.0    diesel
#
#    volume(cm3)     color transmission         drive_unit segment
# 0       1500.0  burgundy    mechanics  front-wheel drive       B
# 1       1300.0     black    mechanics  front-wheel drive       B
# 2       1500.0    silver         auto  front-wheel drive       B
# 3       1400.0     white    mechanics  front-wheel drive       B
# 4       1400.0      gray    mechanics  front-wheel drive       B

# %%
df.tail()
# Out:
#          make model  priceUSD  year     condition  mileage(kilometers)  \
# 56239  lancia  zeta      3650  2000  with mileage             290000.0
# 56240  lancia  zeta      4100  1999  with mileage             340000.0
# 56241  lancia  zeta      3600  1997  with mileage             354000.0
# 56242  lancia  zeta      3000  1997  with mileage             350000.0
# 56243  lancia  zeta      2950  1996  with mileage                  3.0
#
#       fuel_type  volume(cm3)     color transmission         drive_unit segment
# 56239    petrol       2000.0     other    mechanics  front-wheel drive       M
# 56240    diesel       2100.0      blue    mechanics  front-wheel drive       M
# 56241    diesel       2100.0  burgundy    mechanics  front-wheel drive       M
# 56242    petrol       2000.0      blue    mechanics  front-wheel drive       M
# 56243    petrol       2000.0  burgundy    mechanics  front-wheel drive       M

# %%
#columns
df.columns
# Out:
# Index(['make', 'model', 'priceUSD', 'year', 'condition', 'mileage(kilometers)',
#        'fuel_type', 'volume(cm3)', 'color', 'transmission', 'drive_unit',
#        'segment'],
#       dtype='object')

# %%
df.describe()
# Out:
#             priceUSD          year  mileage(kilometers)   volume(cm3)
# count   56244.000000  56244.000000         5.624400e+04  56197.000000
# mean     7415.456440   2003.454840         2.443956e+05   2104.860615
# std      8316.959261      8.144247         3.210307e+05    959.201633
# min        48.000000   1910.000000         0.000000e+00    500.000000
# 25%      2350.000000   1998.000000         1.370000e+05   1600.000000
# 50%      5350.000000   2004.000000         2.285000e+05   1996.000000
# 75%      9807.500000   2010.000000         3.100000e+05   2300.000000
# max    235235.000000   2019.000000         9.999999e+06  20000.000000

# %%
# information about the total number of rows, the number of non-null values in each column, and the data type of each column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56244 entries, 0 to 56243
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make                 56244 non-null  object
#  1   model                56244 non-null  object
#  2   priceUSD             56244 non-null  int64
#  3   year                 56244 non-null  int64
#  4   condition            56244 non-null  object
#  5   mileage(kilometers)  56244 non-null  float64
#  6   fuel_type            56244 non-null  object
#  7   volume(cm3)          56197 non-null  float64
#  8   color                56244 non-null  object
#  9   transmission         56244 non-null  object
#  10  drive_unit           54339 non-null  object
#  11  segment              50953 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 5.1+ MB

# %%
# columns count and names
print ( "columns_count :", df.shape[1])
print ( "row_count :", df.shape[0])
print ("names: ","\n",df.columns)
# Out:
# columns_count : 12
# row_count : 56244
# names:
#  Index(['make', 'model', 'priceUSD', 'year', 'condition', 'mileage(kilometers)',
#        'fuel_type', 'volume(cm3)', 'color', 'transmission', 'drive_unit',
#        'segment'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# make                      0
# model                     0
# priceUSD                  0
# year                      0
# condition                 0
# mileage(kilometers)       0
# fuel_type                 0
# volume(cm3)              47
# color                     0
# transmission              0
# drive_unit             1905
# segment                5291
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56244 entries, 0 to 56243
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make                 56244 non-null  object
#  1   model                56244 non-null  object
#  2   priceUSD             56244 non-null  int64
#  3   year                 56244 non-null  int64
#  4   condition            56244 non-null  object
#  5   mileage(kilometers)  56244 non-null  float64
#  6   fuel_type            56244 non-null  object
#  7   volume(cm3)          56197 non-null  float64
#  8   color                56244 non-null  object
#  9   transmission         56244 non-null  object
#  10  drive_unit           54339 non-null  object
#  11  segment              50953 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 5.1+ MB

# %%
df.shape
# Out:
# (56244, 12)

# %%
#data types
df.dtypes
# Out:
# make                    object
# model                   object
# priceUSD                 int64
# year                     int64
# condition               object
# mileage(kilometers)    float64
# fuel_type               object
# volume(cm3)            float64
# color                   object
# transmission            object
# drive_unit              object
# segment                 object
# dtype: object

# %%
# #this steps for missing value replace
a=df['volume(cm3)'].mode()
a
# Out:
# 0    2000.0
# Name: volume(cm3), dtype: float64

# %%
df['volume(cm3)'].fillna("2000.0",inplace=True)

# %%
b=df['drive_unit'].mode()
b
# Out:
# 0    front-wheel drive
# Name: drive_unit, dtype: object

# %%
df['drive_unit'].fillna("front-wheel drive",inplace=True)

# %%
c=df['segment'].mode()
c
# Out:
# 0    D
# Name: segment, dtype: object

# %%
df['segment'].fillna('D',inplace=True)

# %%
df.isna().sum()
# Out:
# make                   0
# model                  0
# priceUSD               0
# year                   0
# condition              0
# mileage(kilometers)    0
# fuel_type              0
# volume(cm3)            0
# color                  0
# transmission           0
# drive_unit             0
# segment                0
# dtype: int64

# %%
print(df['drive_unit'].value_counts())
print(sns.countplot(x='drive_unit',data=df))
# Out:
# front-wheel drive             39921
# rear drive                     6836
# all-wheel drive                5890
# part-time four-wheel drive     3597
# Name: drive_unit, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
labels = df['drive_unit'].value_counts().index
values = df['drive_unit'].value_counts().values

fig = px.pie(df, values=values, names=labels, title='drive_unit')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(df['segment'].value_counts())
print(sns.countplot(x='segment',data=df))
# Out:
# D    17896
# C    10617
# J     8629
# M     6313
# E     6274
# B     4393
# F      896
# S      765
# A      461
# Name: segment, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
labels = df['segment'].value_counts().index
values = df['segment'].value_counts().values

fig = px.pie(df, values=values, names=labels, title='Segment Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(df['fuel_type'].value_counts())
print(sns.countplot(x='fuel_type',data=df))
# Out:
# petrol        36405
# diesel        19792
# electrocar       47
# Name: fuel_type, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df['transmission'].value_counts())
print(sns.countplot(x='transmission',data=df))
# Out:
# mechanics    36056
# auto         20188
# Name: transmission, dtype: int64
# Axes(0.125,0.11;0.775x0.77)

# %%
labels = df['condition'].value_counts().index
values = df['condition'].value_counts().values

fig = px.pie(df, values=values, names=labels, title='Vehicle Condition')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# preprocessing data(cleaning and organising)
from sklearn.preprocessing import  OrdinalEncoder  #technique used for converting categorical data into numeric values
le=OrdinalEncoder()

# %%
df[['make']]=le.fit_transform(df[['make']])

# %%
df[['condition']]=le.fit_transform(df[['condition']])

# %%
df[['fuel_type']]=le.fit_transform(df[['fuel_type']])

# %%
df[['color']]=le.fit_transform(df[['color']])

# %%
df[['transmission']]=le.fit_transform(df[['transmission']])

# %%
df[['drive_unit']]=le.fit_transform(df[['drive_unit']])

# %%
df[['segment']]=le.fit_transform(df[['segment']])

# %%
df[['model']]=le.fit_transform(df[['model']])

# %%
df.head()
# Out:
#    make  model  priceUSD  year  condition  mileage(kilometers)  fuel_type  \
# 0  52.0   24.0      5500  2008        2.0             162000.0        2.0
# 1  52.0   24.0      5350  2009        2.0             120000.0        2.0
# 2  52.0   24.0      7000  2009        2.0              61000.0        2.0
# 3  52.0   24.0      3300  2003        2.0             265000.0        0.0
# 4  52.0   24.0      5200  2008        2.0              97183.0        0.0
#
#   volume(cm3)  color  transmission  drive_unit  segment
# 0      1500.0    3.0           1.0         1.0      1.0
# 1      1300.0    0.0           1.0         1.0      1.0
# 2      1500.0   10.0           0.0         1.0      1.0
# 3      1400.0   11.0           1.0         1.0      1.0
# 4      1400.0    4.0           1.0         1.0      1.0

# %%
df.dtypes
# Out:
# make                   float64
# model                  float64
# priceUSD                 int64
# year                     int64
# condition              float64
# mileage(kilometers)    float64
# fuel_type              float64
# volume(cm3)             object
# color                  float64
# transmission           float64
# drive_unit             float64
# segment                float64
# dtype: object

# %%
# This code extracts the feature variables and target variable
# input data/feature varible
x=df.drop(["priceUSD"],axis=1)
x
# Out:
#        make   model  year  condition  mileage(kilometers)  fuel_type  \
# 0      52.0    24.0  2008        2.0             162000.0        2.0
# 1      52.0    24.0  2009        2.0             120000.0        2.0
# 2      52.0    24.0  2009        2.0              61000.0        2.0
# 3      52.0    24.0  2003        2.0             265000.0        0.0
# 4      52.0    24.0  2008        2.0              97183.0        0.0
# ...     ...     ...   ...        ...                  ...        ...
# 56239  45.0  1033.0  2000        2.0             290000.0        2.0
# 56240  45.0  1033.0  1999        2.0             340000.0        0.0
# 56241  45.0  1033.0  1997        2.0             354000.0        0.0
# 56242  45.0  1033.0  1997        2.0             350000.0        2.0
# 56243  45.0  1033.0  1996        2.0                  3.0        2.0
#
#       volume(cm3)  color  transmission  drive_unit  segment
# 0          1500.0    3.0           1.0         1.0      1.0
# ...

# %%
y=df['priceUSD']
y
# Out:
# 0        5500
# 1        5350
# 2        7000
# 3        3300
# 4        5200
#          ...
# 56239    3650
# 56240    4100
# 56241    3600
# 56242    3000
# 56243    2950
# Name: priceUSD, Length: 56244, dtype: int64

# %%
# split the feature variables (x) and target variable (y) into training and testing sets.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#        make  model  year  condition  mileage(kilometers)  fuel_type  \
# 48378  79.0  877.0  2003        2.0              0.00000        2.0
# 40436  90.0  703.0  1993        2.0         330000.00000        2.0
# 19224  87.0  269.0  1996        2.0         350000.00000        2.0
# 29610  82.0  519.0  2007        2.0         155000.00000        2.0
# 24545  26.0  401.0  2002        2.0         466708.60000        2.0
# ...     ...    ...   ...        ...                  ...        ...
# 50057  90.0  930.0  2003        2.0         560000.00000        0.0
# 32511  82.0  573.0  2004        2.0         154282.59778        2.0
# 5192   63.0  123.0  2001        2.0         410000.00000        0.0
# 12172   5.0  165.0  1996        2.0         467000.00000        0.0
# 33003  28.0  594.0  1957        2.0         220000.00000        2.0
#
#       volume(cm3)  color  transmission  drive_unit  segment
# 48378      1800.0    3.0           1.0         1.0      3.0
# ...

# %%
x_train
# Out:
#        make  model  year  condition  mileage(kilometers)  fuel_type  \
# 48378  79.0  877.0  2003        2.0              0.00000        2.0
# 40436  90.0  703.0  1993        2.0         330000.00000        2.0
# 19224  87.0  269.0  1996        2.0         350000.00000        2.0
# 29610  82.0  519.0  2007        2.0         155000.00000        2.0
# 24545  26.0  401.0  2002        2.0         466708.60000        2.0
# ...     ...    ...   ...        ...                  ...        ...
# 50057  90.0  930.0  2003        2.0         560000.00000        0.0
# 32511  82.0  573.0  2004        2.0         154282.59778        2.0
# 5192   63.0  123.0  2001        2.0         410000.00000        0.0
# 12172   5.0  165.0  1996        2.0         467000.00000        0.0
# 33003  28.0  594.0  1957        2.0         220000.00000        2.0
#
#       volume(cm3)  color  transmission  drive_unit  segment
# 48378      1800.0    3.0           1.0         1.0      3.0
# ...

# %%
y_test
# Out:
# 24897     6800
# 17238    15500
# 49400     6200
# 41345     4000
# 49070     3273
#          ...
# 13208    10000
# 55716     3500
# 50440    18600
# 17937     3000
# 5887      1283
# Name: priceUSD, Length: 16874, dtype: int64

# %%
y_train
# Out:
# 48378    3208
# 40436     500
# 19224    1700
# 29610    5950
# 24545    8200
#          ...
# 50057    9999
# 32511    5000
# 5192     4500
# 12172    5500
# 33003    2250
# Name: priceUSD, Length: 39370, dtype: int64

# %%
#model creation
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 7075.86896713, 12212.61429638,  9791.2899664 , ...,
#        14130.71986511,  4046.1014203 ,  1866.7650564 ])

# %%
df1=pd.DataFrame({"Actual_value":y_test,"pedicted_value":y_pred,"diffarance":y_test-y_pred})
df1
# Out:
#        Actual_value  pedicted_value   diffarance
# 24897          6800     7075.868967  -275.868967
# 17238         15500    12212.614296  3287.385704
# 49400          6200     9791.289966 -3591.289966
# 41345          4000     6199.791845 -2199.791845
# 49070          3273     3027.569900   245.430100
# ...             ...             ...          ...
# 13208         10000    14435.621981 -4435.621981
# 55716          3500     6572.996749 -3072.996749
# 50440         18600    14130.719865  4469.280135
# 17937          3000     4046.101420 -1046.101420
# 5887           1283     1866.765056  -583.765056
#
# [16874 rows x 3 columns]

# %%
print("constant values is :",model.intercept_)
print("coefficent :")
list(zip(x,model.coef_))
# Out:
# constant values is : -1000425.9363122807
# coefficent :
# [('make', -2.6712678525364293),
#  ('model', -0.32484578717959883),
#  ('year', 502.51191393829936),
#  ('condition', 36.79693604357177),
#  ('mileage(kilometers)', -0.0013059095174347002),
#  ('fuel_type', -513.6621621269875),
#  ('volume(cm3)', 1.2602811440230246),
#  ('color', -57.42065656885372),
#  ('transmission', -2919.5094239516593),
#  ('drive_unit', -378.2421745482213),
#  ('segment', 591.3283546720728)]

# %%
#Evalution performance
# 1. MAE   (mean absolute error)

from sklearn.metrics import mean_absolute_error
print("MAE is :",mean_absolute_error(y_test,y_pred))
# Out:
# MAE is : 3033.5728786071422

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("percentage_error is :",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# percentage_error is : 1.0090008277255245

# %%
# mean_squared_error
from sklearn.metrics import mean_squared_error
print("MSE is :",mean_squared_error(y_test,y_pred))
ae=mean_squared_error(y_test,y_pred)
# Out:
# MSE is : 41467108.2304553

# %%
#root_mean_squared error
print("Root mean squared error :",np.sqrt(ae))
# Out:
# Root mean squared error : 6439.495960900613

# %%
#r2_score
from sklearn.metrics import r2_score
print("r2_score :",r2_score(y_test,y_pred))
# Out:
# r2_score : 0.4433171069181161

# %%
y_pred=model.predict([[5.0,165.0,1996,2.0,467000.00000,0.0,2500.0,10.0,1.0,1.0,4.0]])
y_pred
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([3628.68025642])

# %%
#df['priceUSD'].value_counts()
